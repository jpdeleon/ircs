# %% [markdown]
# # Dipper (sub-)list
#
# The links below show the quick look lightcurve reduced using a K2 data pipeline called [K2SFF](https://archive.stsci.edu/prepds/k2sff/) available online.
#
# * [EPIC203824153](https://www.cfa.harvard.edu/~avanderb/k2c2/ep203824153.html)
# * [EPIC203937317](https://www.cfa.harvard.edu/~avanderb/k2c2/ep203937317.html)
# * [EPIC204278916](https://www.cfa.harvard.edu/~avanderb/k2c2/ep204278916.html)
# * [EPIC204469637](https://www.cfa.harvard.edu/~avanderb/k2c2/ep204469637.html)
# * [EPIC204514548](https://www.cfa.harvard.edu/~avanderb/k2c2/ep204514548.html)
# * [EPIC204630363](https://www.cfa.harvard.edu/~avanderb/k2c2/ep204630363.html)
# * [EPIC204638512](https://www.cfa.harvard.edu/~avanderb/k2c2/ep204638512.html)
# * [EPIC205151387](https://www.cfa.harvard.edu/~avanderb/k2c2/ep205151387.html)
# * [EPIC203384911](https://www.cfa.harvard.edu/~avanderb/k2c2/ep203384911.html)

# %% [markdown]
# ## Overplotting sky locations
#
# * [example](http://nbviewer.jupyter.org/gist/keflavich/bb12b772d6668cf9181a)

# %%
# !conda install -c astropy astroquery --y
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /home/Jerome/miniconda3/envs/ircs_pol:
#
# The following NEW packages will be INSTALLED:
#
#     astroquery:     0.3.5-py27_2  astropy
#     beautifulsoup4: 4.6.0-py27_0
#     html5lib:       0.999-py27_0
#     keyring:        9.0-py27_0    astropy
#     requests:       2.14.2-py27_0
#
# beautifulsoup4 100% |################################| Time: 0:00:00 745.67 kB/s
# keyring-9.0-py 100% |################################| Time: 0:00:00 101.47 kB/s
# astroquery-0.3 100% |################################| Time: 0:00:04 494.18 kB/s

# %%
import astroquery
astroquery.__version__
# Out:
# u'0.3.5'

# %%
from astroquery.skyview import SkyView
from astropy import units as u
from astropy import coordinates

orionkl_coords = coordinates.SkyCoord.from_name('Orion KL')

# %%
orionkl_images = SkyView.get_images(position='Orion KL', survey=['2MASS-K'], pixels=500)
orionkl_images
# Out:
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv8096963280340.fits [Done]
# [[<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f2dd72fb0d0>]]

# %%
# !pip install aplpy
# Out:
# Requirement already satisfied: aplpy in /home/Jerome/miniconda3/envs/ircs_pol/lib/python2.7/site-packages
# Requirement already satisfied: astropy in /home/Jerome/miniconda3/envs/ircs_pol/lib/python2.7/site-packages (from aplpy)
# Requirement already satisfied: numpy>=1.7.0 in /home/Jerome/miniconda3/envs/ircs_pol/lib/python2.7/site-packages (from astropy->aplpy)

# %%
import aplpy
aplpy.__version__
# Out:
# u'1.1.1'

# %%
# %matplotlib inline
fig = aplpy.FITSFigure(orionkl_images[0])
fig.show_grayscale(stretch='arcsinh')
# Out:
# /home/Jerome/miniconda3/envs/ircs_pol/lib/python2.7/site-packages/aplpy/labels.py:432: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self.coord == x or self.axis.apl_tick_positions_world[ipos] > 0:
# INFO: Auto-setting vmin to  2.393e+02 [aplpy.core]
# INFO: Auto-setting vmax to  3.155e+03 [aplpy.core]
